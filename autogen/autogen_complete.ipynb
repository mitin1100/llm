# %%
import os
from dotenv import load_dotenv
from autogen import ConversableAgent, AssistantAgent, UserProxyAgent, GroupChat, GroupChatManager
from autogen.llm_config import LLMConfig
import json
import time
import random

load_dotenv()
# Out:
# True

# %%
import logging

# Suppress API key format warning
logging.getLogger("autogen.oai.client").setLevel(logging.ERROR)

# %% [markdown]
# Conversable Agent

# %%
llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

# Student agent
student = ConversableAgent(
    name="student",
    system_message="You are a curious student. You ask clear, specific questions to learn new concepts.",
    human_input_mode="NEVER",
    llm_config=llm_config
)

# Tutor agent
tutor = ConversableAgent(
    name="tutor",
    system_message="You are a helpful tutor who provides clear and concise explanations suitable for a beginner.",
    human_input_mode="NEVER",
    llm_config=llm_config
)

chat_result = student.initiate_chat(
    recipient=tutor,
    message="Can you explain what a neural network is?",
    max_turns=2,
    summary_method="reflection_with_llm"
)

print("\nFinal Summary:")
print(chat_result.summary)
# Out:
# student (to tutor):
#
# Can you explain what a neural network is?
#
# --------------------------------------------------------------------------------
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# tutor (to student):
#
# Imagine a neural network as a very simplified digital "brain" that learns from examples, much like we do!
#
# Here's the breakdown:
#
# 1.  **Inspired by the Brain:** It's called "neural" because its structure is loosely inspired by the network of neurons in our own brains. It's not a direct copy, but the idea of interconnected units passing information around is similar.
#
# 2.  **Digital "Neurons" (Nodes):**
#     *   The basic building block is a "node" (or "neuron").
#     *   Each node takes several inputs, performs a simple calculation, and then produces an output.
#
# 3.  **Layers of Nodes:**
#     *   These nodes are organized into layers:
#         *   **Input Layer:** Takes in the raw data (e.g., pixels of an image, words in a sentence).
#         *   **Hidden Layers:** One or more layers in between where the complex processing and "thinking" happens. Each node in a hidden layer looks for specific patterns in the data it receives.
#         *   **Output Layer:** Gives the final result (e.g., "this is a cat," "the stock price will go up," "this word means X").
#
# 4.  **How it Learns (Adjusting "Connections"):**
#     *   Initially, a neural network is "dumb" and makes random guesses.
#     *   When it makes a guess, it compares its answer to the *correct* answer.
#     *   Based on how wrong it was, it slightly adjusts the "strength" of the connections (called "weights") between its nodes. Think of it like tuning a radio dial.
#     *   It repeats this process **thousands or millions of times** with many examples. Gradually, by tweaking these connections, it gets better and better at recognizing patterns and making accurate predictions.
#
# **In essence:** A neural network is a powerful system that learns to recognize complex patterns in data by processing many examples and adjusting its internal connections, allowing it to make predictions or classifications without being explicitly programmed for every single scenario.
#
# **Think of it like teaching a child:** You don't give a child a list of rules for what a "cat" is. Instead, you show them many pictures of cats (and not-cats!), say "cat" when appropriate, and over time, they learn to recognize a cat on their own. A neural network learns in a very similar, albeit digital, way.
#
# --------------------------------------------------------------------------------
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# student (to tutor):
#
# That's a great analogy with teaching a child! It makes a lot of sense.
#
# You mentioned that the network adjusts the "strength of the connections" (weights) based on how wrong it was. Can you explain *how* it determines "how wrong" it was, and what process it uses to adjust those weights?
#
# --------------------------------------------------------------------------------
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# tutor (to student):
#
# That's an excellent follow-up question, and it gets to the core of how neural networks truly learn! You're asking about the "engine" that drives the learning process.
#
# Let's break down those two parts:
#
# ---
#
# ### 1. How it Determines "How Wrong" It Was (The Loss Function)
#
# Imagine you're teaching a child to recognize fruits. You show them an apple and ask, "What's this?"
#
# *   **Child's guess:** "Banana!"
# *   **Actual answer:** "Apple."
# *   **How wrong they were:** They were completely wrong. That's a big error!
#
# In a neural network, we use a special mathematical function called a **Loss Function** (or Cost Function, or Error Function) to quantify "how wrong" its prediction was.
#
# *   **The Prediction:** The output layer of the network produces a result (e.g., "0.8 probability of being a cat," or "predicted house price is $300,000").
# *   **The Actual Answer (Ground Truth):** This is the correct answer we already know (e.g., "it *is* a cat," or "actual house price is $320,000").
# *   **The Loss Function's Job:** It takes the network's prediction and the actual answer, compares them, and spits out a single number that represents the "degree of wrongness."
#     *   **If the prediction is very close to the actual answer:** The loss will be a small number (close to zero).
#     *   **If the prediction is very far from the actual answer:** The loss will be a large number.
#
# **Examples of Loss Functions:**
#
# *   **For "Yes/No" or Categorization (like "cat" vs. "dog"):** It might penalize the network more if it was very confident about the wrong answer.
# *   **For Numerical Predictions (like stock price):** A common one is to calculate the difference between the predicted and actual value, and then square it (to make negative differences positive and emphasize larger errors).
#     *   *Example:* Predicted $300,000, Actual $320,000. Difference = -$20,000. Squared difference = $400,000,000. This large number tells the network it was quite wrong.
#
# The ultimate goal during training is to **minimize this loss function**. We want the "degree of wrongness" to be as close to zero as possible.
#
# ---
#
# ### 2. What Process It Uses to Adjust Those Weights (Gradient Descent & Backpropagation)
#
# This is the clever part where the network actually learns! It's a two-step dance:
#
# #### Step 1: Gradient Descent (Finding the "Downhill" Direction)
#
# Imagine you're blindfolded and standing somewhere on a hilly landscape. Your goal is to find the lowest point in the valley (which represents the minimum error).
#
# *   You can't see the whole landscape.
# *   What's the best strategy? Take a small step in the direction that feels steepest **downhill**.
# *   You take a step, feel around again, and repeat the process. Eventually, you'll reach the bottom of a valley.
#
# In our analogy:
# *   **The Landscape:** Represents all possible combinations of weights in the network, and the "height" at any point is the value of the loss function for those weights.
# *   **"Feeling Around":** Mathematically, this involves calculating something called the **gradient**. The gradient tells us the direction of the steepest *increase* in loss.
# *   **"Steepest Downhill":** We want to go in the opposite direction of the gradient to *decrease* the loss.
# *   **"Small Steps":** We adjust the weights by a small amount in that "downhill" direction. This small step size is called the **learning rate**.
#
# So, **Gradient Descent** is the optimization algorithm that iteratively adjusts the weights to move towards the minimum of the loss function.
#
# #### Step 2: Backpropagation (Figuring Out *Which* Weight to Adjust, and By How Much)
#
# Okay, so we know the network was wrong (thanks to the loss function), and we know we need to adjust weights "downhill" (thanks to gradient descent). But how do we know *which specific weight* in the millions of connections should be adjusted, and by how much, when the error only shows up at the *end* of the network?
#
# This is where **Backpropagation** comes in:
#
# 1.  **Error at the Output:** The loss function calculates the error at the very end of the network (the output layer).
# 2.  **Sending Error Backwards:** Backpropagation is the process of taking this error and **propagating it backward** through the network, layer by layer, all the way to the input layer.
# 3.  **Calculating Contribution:** As the error travels backward, it mathematically calculates how much each individual weight and node in the preceding layers contributed to that final error.
#     *   Think of it like an investigation: The final error is the "crime." Backpropagation figures out which "culprit" (weight) was responsible and to what degree.
#     *   Weights that had a larger impact on the final wrong prediction will receive a larger "blame" (or gradient) and thus will be adjusted more significantly.
# 4.  **Weight Update:** Once each weight's contribution to the error is known, the network uses the gradient descent rule to update that specific weight, nudging it in the direction that will reduce the overall loss during the next round.
#
# **In summary:**
#
# *   The **Loss Function** is the scorecard that tells the network *how wrong* it was.
# *   **Gradient Descent** is the strategy to find the lowest score by repeatedly moving "downhill."
# *   **Backpropagation** is the specific mechanism that efficiently figures out *how much each individual connection (weight)* needs to be adjusted to move in that downhill direction, by sending the error signal backward through the network.
#
# This iterative process of **(1) make a prediction, (2) calculate loss, (3) backpropagate error, (4) update weights via gradient descent** is repeated over and over again with thousands or millions of training examples until the network becomes very good at its task.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c2f1e7ee-729d-49d4-963e-4a665b911411): Maximum turns (2) reached
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Final Summary:
# A neural network learns by adjusting the "strength" of connections (weights) between its digital neurons. This adjustment is driven by two key processes:
#
# 1.  **Loss Function:** Quantifies "how wrong" the network's prediction was by comparing its output to the correct answer. A higher loss means a greater error.
# 2.  **Gradient Descent & Backpropagation:**
#     *   **Gradient Descent** is the strategy to minimize the loss, akin to finding the lowest point in a valley by taking small steps in the steepest "downhill" direction.
#     *   **Backpropagation** is the specific algorithm that efficiently calculates how much each individual weight contributed to the overall error (by propagating the error backward through the network), enabling gradient descent to know precisely how to adjust each weight to reduce the loss in subsequent predictions.

# %% [markdown]
# Creating Specialized Agent

# %%
# Create a Technical Expert Agent
tech_expert = ConversableAgent(
    name="tech_expert",
    system_message="""You are a senior software engineer with expertise in Python, AI, and system design.
    Provide technical, detailed explanations with code examples when appropriate.
    Always consider best practices and performance implications.""",
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# Create a Creative Writer Agent
creative_writer = ConversableAgent(
    name="creative_writer",
    system_message="""You are a creative writer and storyteller.
    Your responses are engaging, imaginative, and use vivid descriptions.
    You excel at making complex topics accessible through stories and analogies.""",
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# Create a Business Analyst Agent
business_analyst = ConversableAgent(
    name="business_analyst",
    system_message="""You are a business analyst focused on ROI, efficiency, and strategic planning.
    Always consider business impact, costs, and practical implementation.
    Provide actionable recommendations with clear metrics.""",
    llm_config=llm_config,
    human_input_mode="NEVER"
)


agents = [tech_expert, creative_writer, business_analyst]
print("Specialized agents created!")
for agent in agents:
    print(f"- {agent.name}: {agent.system_message.split('.')[0]}.")
# Out:
# Specialized agents created!
# - tech_expert: You are a senior software engineer with expertise in Python, AI, and system design.
# - creative_writer: You are a creative writer and storyteller.
# - business_analyst: You are a business analyst focused on ROI, efficiency, and strategic planning.

# %% [markdown]
# Built-in Agent type

# %%
# %pip install matplotlib numpy pyautogen

# %%
from autogen.coding import LocalCommandLineCodeExecutor

import sys
# !{sys.executable} -m pip install numpy matplotlib


llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

# Create assistant agent
assistant = AssistantAgent(
    name="assistant",
    system_message="You are a helpful assistant who writes and explains Python code clearly.",
    llm_config=llm_config
)

# Create user proxy agent
user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=5,
    # code_execution_config=False,
    code_execution_config={
        "executor": LocalCommandLineCodeExecutor(work_dir="coding", timeout=30),
    },
)

chat_result = user_proxy.initiate_chat(
    recipient=assistant,
    message="Plot a sine wave using matplotlib from -2π to 2π and save the plot as sine_wave.png.",
    max_turns=4,
    summary_method="reflection_with_llm"
)

from IPython.display import Image, display
import os

image_path = "coding/sine_wave.png"
if os.path.exists(image_path):
    display(Image(filename=image_path))
else:
    print("Plot not found.")

# Step 6: Print summary
print("\nFinal Summary:")
print(chat_result.summary)

# %% [markdown]
# Human in the loop

# %% [markdown]
# Bug triage bot

# %%
import random

llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

triage_system_message = """
You are a bug triage assistant. You will be given bug report summaries.

For each bug:
- If it is urgent (e.g., 'crash', 'security', or 'data loss' is mentioned), escalate it and ask the human agent for confirmation.
- If it seems minor (e.g., cosmetic, typo), suggest closing it but still ask for human review.
- Otherwise, classify it as medium priority and ask the human for review.

Once all bugs are processed, summarize what was escalated, closed, or marked as medium priority.
End by saying: "You can type exit to finish."
"""

# Create assistant agent
triage_bot = ConversableAgent(
    name="triage_bot",
    system_message=triage_system_message,
    llm_config=llm_config
)

# Create human agent
human = ConversableAgent(
    name="human",
    human_input_mode="ALWAYS",
)


BUGS = [
    "App crashes when opening user profile.",
    "Minor UI misalignment on settings page.",
    "Password reset email not sent consistently.",
    "Typo in the About Us footer text.",
    "Database connection timeout under heavy load.",
    "Login form allows SQL injection attack.",
]

random.shuffle(BUGS)
selected_bugs = BUGS[:3]

initial_prompt = (
    "Please triage the following bug reports one by one:\n\n" +
    "\n".join([f"{i+1}. {bug}" for i, bug in enumerate(selected_bugs)])
)

# Step 7: Start conversation
human.initiate_chat(
    recipient=triage_bot,
    message=initial_prompt,
)

# %% [markdown]
# Agent Orchestration and multi agent system

# %% [markdown]
# Groupchat for lesson learning

# %%
llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

# System messages
planner_message = "Create a short lesson plan for 4th graders."
reviewer_message = "Review a plan and suggest up to 3 brief edits."
teacher_message = "Suggest a topic and reply DONE when satisfied."

lesson_planner = ConversableAgent(
    name="planner_agent",
    system_message=planner_message,
    description="Makes lesson plans.",
    llm_config=llm_config
)

lesson_reviewer = ConversableAgent(
    name="reviewer_agent",
    system_message=reviewer_message,
    description="Reviews lesson plans and suggests edits.",
    llm_config=llm_config
)

teacher = ConversableAgent(
    name="teacher_agent",
    system_message=teacher_message,
    llm_config=llm_config,
    is_termination_msg=lambda x: "DONE" in (x.get("content", "") or "").upper()
)

# Create group chat
groupchat = GroupChat(
    agents=[teacher, lesson_planner, lesson_reviewer],
    speaker_selection_method="auto"
)

# Create manager
manager = GroupChatManager(
    name="group_manager",
    groupchat=groupchat,
    llm_config=llm_config
)

teacher.initiate_chat(
    recipient=manager,
    message="Make a simple lesson about the moon.",
    max_turns=6,
    summary_method="reflection_with_llm"
)

# %% [markdown]
# Tool and Extensions

# %%
from autogen import ConversableAgent, register_function
from typing import Annotated

llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

# Define function
def is_prime(n: Annotated[int, "Positive integer"]) -> str:
    if n < 2:
        return "No"
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return "No"
    return "Yes"

# Create agents
math_asker = ConversableAgent(
    name="math_asker",
    system_message="Ask whether a number is prime.",
    llm_config=llm_config
)

math_checker = ConversableAgent(
    name="math_checker",
    human_input_mode="NEVER",
    llm_config=llm_config
)

# Register function
register_function(
    is_prime,
    caller=math_asker,
    executor=math_checker,
    description="Check if a number is prime. Returns Yes or No."
)

# Start conversation
math_checker.initiate_chat(
    recipient=math_asker,
    message="Is 72 a prime number?",
    max_turns=2
)

# %% [markdown]
# Structured Output

# %%
from pydantic import BaseModel
from autogen import ConversableAgent

# Define structured output model
class TicketSummary(BaseModel):
    customer_name: str
    issue_type: str
    urgency_level: str
    recommended_action: str

llm_config = LLMConfig(
    {"api_type": "google", "model": "gemini-2.5-flash", "api_key": os.environ["GEMINI_API_KEY"]}
)

# Create agent
support_agent = ConversableAgent(
    name="support_agent",
    system_message=(
        "You are a support assistant. Summarize a customer ticket using:"
        "\n- customer_name"
        "\n- issue_type (e.g. login issue, billing problem, bug report)"
        "\n- urgency_level (Low, Medium, High)"
        "\n- recommended_action"
    ),
    llm_config=llm_config
)

# Start conversation
support_agent.initiate_chat(
    recipient=support_agent,
    message="Ticket: John Doe is unable to reset his password and has an important meeting in 30 minutes.",
    max_turns=1
)
